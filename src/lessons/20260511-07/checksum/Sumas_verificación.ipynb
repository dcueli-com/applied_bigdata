# %%
# !apt-get update -y
# !apt-get install openjdk-11-jdk -y
# Out:
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:8 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [91.2 kB]
# Get:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:10 https://cli.github.com/packages stable/main amd64 Packages [356 B]
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,915 kB]
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# ...

# %%
# !java -version
# Out:
# openjdk version "17.0.17" 2025-10-21
# OpenJDK Runtime Environment (build 17.0.17+10-Ubuntu-122.04)
# OpenJDK 64-Bit Server VM (build 17.0.17+10-Ubuntu-122.04, mixed mode, sharing)

# %%
# !wget -q https://archive.apache.org/dist/hadoop/common/hadoop-3.3.1/hadoop-3.3.1.tar.gz
# !tar -xzf hadoop-3.3.1.tar.gz
# !mv hadoop-3.3.1 hadoop

# %%
import os

os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-11-openjdk-amd64"

os.environ["HADOOP_HOME"] = "/content/hadoop"

os.environ["PATH"] += os.pathsep + os.path.join(os.environ["HADOOP_HOME"], "bin")

# !echo "JAVA_HOME=$JAVA_HOME"
# !echo "HADOOP_HOME=$HADOOP_HOME"
# Out:
# JAVA_HOME=/usr/lib/jvm/java-11-openjdk-amd64
# HADOOP_HOME=/content/hadoop

# %%
# !echo "Y" | hadoop/bin/hdfs namenode -format
# Out:
# WARNING: /content/hadoop/logs does not exist. Creating.
# 2026-03-10 07:44:48,869 INFO namenode.NameNode: STARTUP_MSG:
# /************************************************************
# STARTUP_MSG: Starting NameNode
# STARTUP_MSG:   host = 281c70bab7d7/172.28.0.12
# STARTUP_MSG:   args = [-format]
# STARTUP_MSG:   version = 3.3.1
# ...

# %%
# !hadoop/bin/hdfs --daemon start namenode
# !hadoop/bin/hdfs --daemon start datanode

# %%
# !hadoop/bin/hdfs dfs -ls /
# Out:
# Found 28 items
# -rwxr-xr-x   1 root root          0 2026-03-10 07:15 /.dockerenv
# drwxr-xr-x   - root root       4096 2026-03-10 07:16 /bin
# drwxr-xr-x   - root root       4096 2022-04-18 10:28 /boot
# drwxr-xr-x   - root root       4096 2026-03-10 07:44 /content
# drwxr-xr-x   - root root       4096 2026-03-05 14:11 /datalab
# drwxr-xr-x   - root root        360 2026-03-10 07:15 /dev
# drwxr-xr-x   - root root       4096 2026-03-10 07:16 /etc
# drwxr-xr-x   - root root       4096 2022-04-18 10:28 /home
# drwxr-xr-x   - root root       4096 2026-03-10 07:15 /kaggle
# drwxr-xr-x   - root root       4096 2026-01-16 14:10 /lib
# drwxr-xr-x   - root root       4096 2026-01-09 02:03 /lib32
# drwxr-xr-x   - root root       4096 2026-01-09 02:10 /lib64
# drwxr-xr-x   - root root       4096 2026-01-09 02:03 /libx32
# drwxr-xr-x   - root root       4096 2026-01-09 02:03 /media
# drwxr-xr-x   - root root       4096 2026-01-09 02:03 /mnt
# ...

# %%
# !hadoop/bin/hdfs dfs -ls /
# Out:
# Found 28 items
# -rwxr-xr-x   1 root root          0 2026-03-10 07:15 /.dockerenv
# drwxr-xr-x   - root root       4096 2026-03-10 07:16 /bin
# drwxr-xr-x   - root root       4096 2022-04-18 10:28 /boot
# drwxr-xr-x   - root root       4096 2026-03-10 07:44 /content
# drwxr-xr-x   - root root       4096 2026-03-05 14:11 /datalab
# drwxr-xr-x   - root root        360 2026-03-10 07:15 /dev
# drwxr-xr-x   - root root       4096 2026-03-10 07:16 /etc
# drwxr-xr-x   - root root       4096 2022-04-18 10:28 /home
# drwxr-xr-x   - root root       4096 2026-03-10 07:15 /kaggle
# drwxr-xr-x   - root root       4096 2026-01-16 14:10 /lib
# drwxr-xr-x   - root root       4096 2026-01-09 02:03 /lib32
# drwxr-xr-x   - root root       4096 2026-01-09 02:10 /lib64
# drwxr-xr-x   - root root       4096 2026-01-09 02:03 /libx32
# drwxr-xr-x   - root root       4096 2026-01-09 02:03 /media
# drwxr-xr-x   - root root       4096 2026-01-09 02:03 /mnt
# ...

# %%
# !jps
# Out:
# 8459 Jps

# %%
# !hadoop/bin/hdfs --daemon start namenode
# !hadoop/bin/hdfs --daemon start datanode

# %%
# !hadoop/bin/hdfs dfs -ls /
# Out:
# Found 28 items
# -rwxr-xr-x   1 root root          0 2026-03-10 07:15 /.dockerenv
# drwxr-xr-x   - root root       4096 2026-03-10 07:16 /bin
# drwxr-xr-x   - root root       4096 2022-04-18 10:28 /boot
# drwxr-xr-x   - root root       4096 2026-03-10 07:44 /content
# drwxr-xr-x   - root root       4096 2026-03-05 14:11 /datalab
# drwxr-xr-x   - root root        360 2026-03-10 07:15 /dev
# drwxr-xr-x   - root root       4096 2026-03-10 07:16 /etc
# drwxr-xr-x   - root root       4096 2022-04-18 10:28 /home
# drwxr-xr-x   - root root       4096 2026-03-10 07:15 /kaggle
# drwxr-xr-x   - root root       4096 2026-01-16 14:10 /lib
# drwxr-xr-x   - root root       4096 2026-01-09 02:03 /lib32
# drwxr-xr-x   - root root       4096 2026-01-09 02:10 /lib64
# drwxr-xr-x   - root root       4096 2026-01-09 02:03 /libx32
# drwxr-xr-x   - root root       4096 2026-01-09 02:03 /media
# drwxr-xr-x   - root root       4096 2026-01-09 02:03 /mnt
# ...

# %%
# !hadoop/bin/hdfs dfsadmin -report
# Out:
# report: FileSystem file:/// is not an HDFS file system. The fs class is: org.apache.hadoop.fs.LocalFileSystem
# Usage: hdfs dfsadmin [-report] [-live] [-dead] [-decommissioning] [-enteringmaintenance] [-inmaintenance]

# %%
config_core_site = """<configuration>
    <property>
        <name>fs.defaultFS</name>
        <value>hdfs://localhost:9000</value>
    </property>
</configuration>"""

with open("/content/hadoop/etc/hadoop/core-site.xml", "w") as file:
    file.write(config_core_site)

# %%
# !cat /content/hadoop/etc/hadoop/core-site.xml
# Out:
# <configuration>
#     <property>
#         <name>fs.defaultFS</name>
#         <value>hdfs://localhost:9000</value>
#     </property>
# </configuration>

# %%
# !echo "Y" | hadoop/bin/hdfs namenode -format
# Out:
# 2025-02-10 12:16:14,986 INFO namenode.NameNode: STARTUP_MSG:
# /************************************************************
# STARTUP_MSG: Starting NameNode
# STARTUP_MSG:   host = 28c1f5f76347/172.28.0.12
# STARTUP_MSG:   args = [-format]
# STARTUP_MSG:   version = 3.3.1
# ...

# %%
# !hadoop/bin/hdfs --daemon start namenode
# !hadoop/bin/hdfs --daemon start datanode

# %%
# !hadoop/bin/hdfs dfsadmin -report
# Out:
# Configured Capacity: 115658190848 (107.72 GB)
# Present Capacity: 80569921536 (75.04 GB)
# DFS Remaining: 80569896960 (75.04 GB)
# DFS Used: 24576 (24 KB)
# DFS Used%: 0.00%
# Replicated Blocks:
# 	Under replicated blocks: 0
# 	Blocks with corrupt replicas: 0
# 	Missing blocks: 0
# 	Missing blocks (with replication factor 1): 0
# 	Low redundancy blocks with highest priority to recover: 0
# 	Pending deletion blocks: 0
# Erasure Coded Block Groups:
# 	Low redundancy block groups: 0
# 	Block groups with corrupt internal blocks: 0
# 	Missing block groups: 0
# 	Low redundancy blocks with highest priority to recover: 0
# 	Pending deletion blocks: 0
#
# -------------------------------------------------
# Live datanodes (1):
#
# Name: 127.0.0.1:9866 (localhost)
# Hostname: 28c1f5f76347
# Decommission Status : Normal
# Configured Capacity: 115658190848 (107.72 GB)
# DFS Used: 24576 (24 KB)
# Non DFS Used: 35071492096 (32.66 GB)
# DFS Remaining: 80569896960 (75.04 GB)
# DFS Used%: 0.00%
# ...

# %%
# !hadoop/bin/hdfs dfs -ls /

# %%
# !jps
# Out:
# 4401 NameNode
# 4468 DataNode
# 4989 Jps

# %%
# !hadoop/bin/hdfs dfs -ls /

# %%
# !hadoop/bin/hdfs dfs -mkdir -p /user/alumno/cluster_origen
# !hadoop/bin/hdfs dfs -mkdir -p /user/alumno/cluster_destino

# %%
# !hadoop/bin/hdfs dfs -ls /user/alumno
# Out:
# Found 2 items
# drwxr-xr-x   - root supergroup          0 2025-02-10 12:18 /user/alumno/cluster_destino
# drwxr-xr-x   - root supergroup          0 2025-02-10 12:18 /user/alumno/cluster_origen

# %%
import pandas as pd

df = pd.DataFrame({
    'ID': [1, 2, 3, 4, 5],
    'Nombre': ['Ana', 'Juan', 'Carlos', 'Marta', 'Lucia'],
    'Edad': [23, 34, 28, 45, 37]
})

df.to_csv("datos.csv", index=False)

# %%
# !hadoop/bin/hdfs dfs -put datos.csv /user/alumno/cluster_origen/

# %%
# !hadoop/bin/hdfs dfs -ls /user/alumno/cluster_origen
# Out:
# Found 1 items
# -rw-r--r--   3 root supergroup         68 2025-02-10 12:19 /user/alumno/cluster_origen/datos.csv

# %%
# !hadoop/bin/hdfs dfs -cp /user/alumno/cluster_origen/datos.csv /user/alumno/cluster_destino/

# %%
# !hadoop/bin/hdfs dfs -ls /user/alumno/cluster_destino
# Out:
# Found 1 items
# -rw-r--r--   3 root supergroup         68 2025-02-10 12:20 /user/alumno/cluster_destino/datos.csv

# %%
# !hadoop/bin/hdfs dfs -checksum /user/alumno/cluster_origen/datos.csv
# !hadoop/bin/hdfs dfs -checksum /user/alumno/cluster_destino/datos.csv
# Out:
# /user/alumno/cluster_origen/datos.csv	MD5-of-0MD5-of-512CRC32C	000002000000000000000000a8e82670901736882f273adfb8bff961
# /user/alumno/cluster_destino/datos.csv	MD5-of-0MD5-of-512CRC32C	000002000000000000000000a8e82670901736882f273adfb8bff961

# %%
# !hadoop/bin/hdfs dfs -ls /user/alumno/cluster_destino/datos.csv
# Out:
# -rw-r--r--   3 root supergroup         68 2025-02-10 12:20 /user/alumno/cluster_destino/datos.csv

# %%
# !hadoop/bin/hdfs dfs -chmod 700 /user/alumno/cluster_destino/datos.csv
# !hadoop/bin/hdfs dfs -ls /user/alumno/cluster_destino
# Out:
# Found 1 items
# -rwx------   3 root supergroup         68 2025-02-10 12:20 /user/alumno/cluster_destino/datos.csv
